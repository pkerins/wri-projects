# %% [markdown]
# ### Data
# ene.025 Renewable Energy Investment by Sector <br>
# https://resourcewatch.carto.com/u/wri-rw/dataset/ene_025_renewable_energy_investment_by_sector <br>

# %%
import numpy as np
import vega
import json
from vega import Vega

# %% [markdown]
# ### Resource Watch specification
# API ID: 118f245b-bf0f-47a0-be1e-3915a3a62cf6 <br>
# https://resourcewatch.org/embed/widget/118f245b-bf0f-47a0-be1e-3915a3a62cf6

# %%
specV3=json.loads("""
{
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT year as x, metal_ores, fossil_fuels, non_metallic_minerals, biomass FROM dash_0078_global_raw_material_extraction ORDER BY x ASC",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "formula",
          "as": "metal_ores",
          "expr": "datum.metal_ores*1000"
        },
        {
          "type": "formula",
          "as": "fossil_fuels",
          "expr": "datum.fossil_fuels*1000"
        },
        {
          "type": "formula",
          "as": "non_metallic_minerals",
          "expr": "datum.non_metallic_minerals*1000"
        },
        {
          "type": "formula",
          "as": "biomass",
          "expr": "datum.biomass*1000"
        },
        {
          "type": "fold",
          "as": [
            "c",
            "y"
          ],
          "fields": [
            "non_metallic_minerals",
            "metal_ores",
            "fossil_fuels",
            "biomass"
          ]
        },
        {
          "type": "stack",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c",
            "order": "ascending"
          },
          "field": "y"
        },
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(upper(slice(datum.c,0,1))+slice(datum.c,1),/_/g,' ')"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "Extracted Material (tonnes)",
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "format": "s",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Material Type",
      "fill": "color",
      "orient": "right"
    }
  ],
  "interaction_config": [
    {
      "name": "tooltip",
      "config": {
        "fields": [
          {
            "column": "y",
            "property": "Mass (t)",
            "type": "number",
            "format": ".2s"
          },
          {
            "column": "c",
            "property": "Type",
            "type": "string"
          },
          {
            "column": "x",
            "property": "Year",
            "type": "string"
          }
        ]
      }
    }
  ]
}
""")
vega4view=dict(specV3)
vega4view['width']=300
vega4view['height']=300
Vega(vega4view)
# Out:
# <div class="vega-embed" id="15c8869f-273d-4050-aa06-91918ea23c8c"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ### Stand-alone specification
# (eg for use with https://vega.github.io/editor/#/)

# %%
specV3=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "type": "pad",
    "resize": true,
    "contains": "padding"
  },
  "data": [
    {
      "name": "table",
      "url": "https://wri-rw.carto.com/api/v2/sql?q=SELECT year as x, metal_ores, fossil_fuels, non_metallic_minerals, biomass FROM dash_0078_global_raw_material_extraction ORDER BY x ASC",
      "format": {
        "type": "json",
        "property": "rows"
      },
      "transform": [
        {
          "type": "formula",
          "as": "metal_ores",
          "expr": "datum.metal_ores*1000"
        },
        {
          "type": "formula",
          "as": "fossil_fuels",
          "expr": "datum.fossil_fuels*1000"
        },
        {
          "type": "formula",
          "as": "non_metallic_minerals",
          "expr": "datum.non_metallic_minerals*1000"
        },
        {
          "type": "formula",
          "as": "biomass",
          "expr": "datum.biomass*1000"
        },
        {
          "type": "fold",
          "as": [
            "c",
            "y"
          ],
          "fields": [
            "non_metallic_minerals",
            "metal_ores",
            "fossil_fuels",
            "biomass"
          ]
        },
        {
          "type": "stack",
          "groupby": [
            "x"
          ],
          "sort": {
            "field": "c",
            "order": "ascending"
          },
          "field": "y"
        },
        {
          "type": "formula",
          "as": "c",
          "expr": "replace(upper(slice(datum.c,0,1))+slice(datum.c,1),/_/g,' ')"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "x",
      "type": "band",
      "range": "width",
      "domain": {
        "data": "table",
        "field": "x"
      }
    },
    {
      "name": "y",
      "type": "linear",
      "range": "height",
      "nice": true,
      "zero": true,
      "domain": {
        "data": "table",
        "field": "y1"
      }
    },
    {
      "name": "color",
      "type": "ordinal",
      "range": "category",
      "domain": {
        "data": "table",
        "field": "c"
      }
    }
  ],
  "axes": [
    {
      "orient": "bottom",
      "scale": "x",
      "zindex": 1,
      "labelOverlap": "parity",
      "labelPadding": 6,
      "encode": {
        "labels": {
          "update": {
            "angle": {
              "value": 90
            },
            "align": {
              "value": "left"
            },
            "baseline": {
              "value": "middle"
            }
          }
        }
      }
    },
    {
      "title": "Extracted Material (tonnes)",
      "orient": "left",
      "scale": "y",
      "zindex": 0,
      "format": "s",
      "labelOverlap": "parity"
    }
  ],
  "marks": [
    {
      "type": "rect",
      "from": {
        "data": "table"
      },
      "encode": {
        "enter": {
          "x": {
            "scale": "x",
            "field": "x"
          },
          "width": {
            "scale": "x",
            "band": 1,
            "offset": -1
          },
          "y": {
            "scale": "y",
            "field": "y0"
          },
          "y2": {
            "scale": "y",
            "field": "y1"
          },
          "fill": {
            "scale": "color",
            "field": "c"
          }
        },
        "update": {
          "fillOpacity": {
            "value": 1
          }
        },
        "hover": {
          "fillOpacity": {
            "value": 0.5
          },
          "tooltip": {
            "signal": "{'Mass': format(datum.y,'.3s') + ' t','Type':datum.c, 'Year':datum.x}"
          }
        }
      }
    }
  ],
  "legends": [
    {
      "title": "Material Type",
      "fill": "color",
      "orient": "right"
    }
  ]
}
""")
vega4view=dict(specV3)
Vega(vega4view)
# Out:
# <div class="vega-embed" id="120d4731-273d-4390-9a10-7f208cde84c9"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
