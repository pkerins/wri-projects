# %% [markdown]
# ### Data
# Conflict events <br>
# Dataset ID `c6e02718-decb-41e5-bc0c-8f0ab6f4078e` <br>

# %%
import numpy as np
import vega
import json
from vega import Vega

# %% [markdown]
# ### Template specification
# (for WPS Global Tool backoffice; cannot be created directly)

# %%
{
  "width": 300,
  "height": 300,
  "autosize": {
    "contains": "padding",
    "resize": true,
    "type": "pad"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "update": "datum",
          "events": "@cell:mouseover"
        },
        {
          "update": "null",
          "events": "@cell:mouseout"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "widget_datapoints",
      "urlTemplate": "api/v1/widget_datapoints/${region.gid_2}/acled_fatalities/",
      "format": {
        "property": "widget_datapoints",
        "type": "json",
        "parse": {
          "month_indep": "date:'%Y-%m-%d'"
        }
      },
      "transform": [
        {
          "type": "formula",
          "as": "month",
          "expr": "month(datum.month_indep)"
          }
      ]
    },
    {
      "name": "dots",
      "source": "widget_datapoints",
      "transform": [
        {
          "expr": "hover && hover.datum.month_indep === datum.month_indep",
          "type": "filter"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "month_indep",
      "type": "time",
      "range": "width",
      "domain": {
        "data": "widget_datapoints",
        "field": "month_indep"
      }
    },
    {
      "name": "acled_fatalities",
      "type": "linear",
      "range": "height",
      "zero": true,
      "nice": true,
      "domain": {
        "data": "widget_datapoints",
        "field": "acled_fatalities"
      }
    }
  ],
  "axes": [
    {
      "labelOverlap": "parity",
      "scale": "month_indep",
      "zindex": 1,
      "orient": "bottom",
      "formatType": "time",
      "format": "%Y"
    },
    {
      "title": "Fatalities",
      "scale": "acled_fatalities",
      "labelOverlap": "parity",
      "format": "",
      "grid": true,
      "zindex": 0,
      "orient": "left"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "interactive": false,
      "type": "line",
      "encode": {
        "enter": {
          "y": {
            "field": "acled_fatalities",
            "scale": "acled_fatalities"
          },
          "x": {
            "field": "month_indep",
            "scale": "month_indep"
          }
        }
      },
      "from": {
        "data": "widget_datapoints"
      }
    },
    {
      "name": "points",
      "type": "symbol",
      "interactive": false,
      "encode": {
        "update": {
          "opacity": {
            "value": 1
          }
        },
        "enter": {
          "y": {
            "field": "acled_fatalities",
            "scale": "acled_fatalities"
          },
          "x": {
            "field": "month_indep",
            "scale": "month_indep"
          }
        }
      },
      "from": {
        "data": "dots"
      }
    },
    {
      "name": "cell",
      "type": "path",
      "encode": {
        "update": {
          "opacity": {
            "value": 0
          },
          "path": {
            "field": "path"
          },
          "fill": {
            "value": "red"
          }
        },
        "hover": {
          "tooltip": {
            "signal": "{'Fatalities': format(hover.datum['acled_fatalities'], ''), 'Date': timeFormat(hover.datum.month_indep,'%b %Y')}"
          }
        }
      },
      "transform": [
        {
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ],
          "y": "datum.y",
          "x": "datum.x",
          "type": "voronoi"
        }
      ],
      "from": {
        "data": "lines"
      }
    }
  ]
}

# %% [markdown]
# ### Stand-alone specification
# (eg for use with https://vega.github.io/editor/#/)

# %% [markdown]
# Preview region `ETH.1.1_1` <br>
# url `https://waterpeacesecurity.org/api/v1/widget_datapoints/ETH.1.1_1/battles_fatalities_12m/` <br>

# %%
specV5=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "contains": "padding",
    "resize": true,
    "type": "pad"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "update": "datum",
          "events": "@cell:mouseover"
        },
        {
          "update": "null",
          "events": "@cell:mouseout"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "widget_datapoints",
      "url": "https://waterpeacesecurity.org/api/v1/widget_datapoints/ETH.1.1_1/acled_fatalities/",
      "format": {
        "property": "widget_datapoints",
        "type": "json",
        "parse": {
          "month_indep": "date:'%Y-%m-%d'"
        }
      },
      "transform": [
        {
          "type": "formula",
          "as": "month",
          "expr": "month(datum.month_indep)"
          }
      ]
    },
    {
      "name": "dots",
      "source": "widget_datapoints",
      "transform": [
        {
          "expr": "hover && hover.datum.month_indep === datum.month_indep",
          "type": "filter"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "month_indep",
      "type": "time",
      "range": "width",
      "domain": {
        "data": "widget_datapoints",
        "field": "month_indep"
      }
    },
    {
      "name": "acled_fatalities",
      "type": "linear",
      "range": "height",
      "zero": true,
      "nice": true,
      "domain": {
        "data": "widget_datapoints",
        "field": "acled_fatalities"
      }
    }
  ],
  "axes": [
    {
      "labelOverlap": "parity",
      "scale": "month_indep",
      "zindex": 1,
      "orient": "bottom",
      "formatType": "time",
      "format": "%Y"
    },
    {
      "title": "Fatalities",
      "scale": "acled_fatalities",
      "labelOverlap": "parity",
      "format": "",
      "grid": true,
      "zindex": 0,
      "orient": "left"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "interactive": false,
      "type": "line",
      "encode": {
        "enter": {
          "y": {
            "field": "acled_fatalities",
            "scale": "acled_fatalities"
          },
          "x": {
            "field": "month_indep",
            "scale": "month_indep"
          }
        }
      },
      "from": {
        "data": "widget_datapoints"
      }
    },
    {
      "name": "points",
      "type": "symbol",
      "interactive": false,
      "encode": {
        "update": {
          "opacity": {
            "value": 1
          }
        },
        "enter": {
          "y": {
            "field": "acled_fatalities",
            "scale": "acled_fatalities"
          },
          "x": {
            "field": "month_indep",
            "scale": "month_indep"
          }
        }
      },
      "from": {
        "data": "dots"
      }
    },
    {
      "name": "cell",
      "type": "path",
      "encode": {
        "update": {
          "opacity": {
            "value": 0
          },
          "path": {
            "field": "path"
          },
          "fill": {
            "value": "red"
          }
        },
        "hover": {
          "tooltip": {
            "signal": "{'Fatalities': format(hover.datum['acled_fatalities'], ''), 'Date': timeFormat(hover.datum.month_indep,'%b %Y')}"
          }
        }
      },
      "transform": [
        {
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ],
          "y": "datum.y",
          "x": "datum.x",
          "type": "voronoi"
        }
      ],
      "from": {
        "data": "lines"
      }
    }
  ]
}
""")
vega5view=dict(specV5)
Vega(vega5view)
