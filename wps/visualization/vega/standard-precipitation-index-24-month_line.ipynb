# %% [markdown]
# ### Data
# 24-Month Standard Precipitation Index <br>
# Dataset ID `2c34d37c-d8e5-461b-816e-48ef825196cd` <br>

# %%
import numpy as np
import vega
import json
from vega import Vega

# %% [markdown]
# ### Template specification
# (for WPS Global Tool backoffice; cannot be created directly)

# %%
{
  "width": 300,
  "height": 300,
  "autosize": {
    "contains": "padding",
    "resize": true,
    "type": "pad"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "update": "datum",
          "events": "@cell:mouseover"
        },
        {
          "update": "null",
          "events": "@cell:mouseout"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "widget_datapoints",
      "urlTemplate": "/api/v1/widget_datapoints/${region.gid_2}/spi_24/",
      "format": {
        "property": "widget_datapoints",
        "type": "json",
        "parse": {
          "month_indep": "date:'%Y-%m-%d'"
        }
      }
    },
    {
      "name": "dots",
      "source": "widget_datapoints",
      "transform": [
        {
          "expr": "hover && hover.datum.month_indep === datum.month_indep",
          "type": "filter"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "year",
      "type": "linear",
      "range": "width",
      "zero": false,
      "nice": false,
      "domain": {
        "data": "widget_datapoints",
        "field": "year"
      }
    },
    {
      "name": "month_indep",
      "type": "time",
      "range": "width",
      "domain": {
        "data": "widget_datapoints",
        "field": "month_indep"
      }
    },
    {
      "name": "spi_24",
      "type": "linear",
      "range": "height",
      "zero": true,
      "nice": true,
      "domain": {
        "data": "widget_datapoints",
        "field": "spi_24"
      }
    }
  ],
  "axes": [
    {
      "labelOverlap": "parity",
      "scale": "year",
      "format": "4f",
      "zindex": 1,
      "orient": "bottom"
    },
    {
      "title": "24-Month Standard Precipitation Index",
      "scale": "spi_24",
      "labelOverlap": "parity",
      "format": "2s",
      "grid": true,
      "zindex": 0,
      "orient": "left"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "interactive": false,
      "type": "line",
      "encode": {
        "enter": {
          "y": {
            "field": "spi_24",
            "scale": "spi_24"
          },
          "x": {
            "field": "month_indep",
            "scale": "month_indep"
          }
        }
      },
      "from": {
        "data": "widget_datapoints"
      }
    },
    {
      "name": "points",
      "type": "symbol",
      "interactive": false,
      "encode": {
        "update": {
          "opacity": {
            "value": 1
          }
        },
        "enter": {
          "y": {
            "field": "spi_24",
            "scale": "spi_24"
          },
          "x": {
            "field": "month_indep",
            "scale": "month_indep"
          }
        }
      },
      "from": {
        "data": "dots"
      }
    },
    {
      "name": "cell",
      "type": "path",
      "encode": {
        "update": {
          "opacity": {
            "value": 0
          },
          "path": {
            "field": "path"
          },
          "fill": {
            "value": "red"
          }
        },
        "hover": {
          "tooltip": {
            "signal": "{'Standard Precipitation Index': format(hover.datum.spi_24, '.3f'), 'Date': timeFormat(hover.datum.month_indep,'%b %Y')}"
          }
        }
      },
      "transform": [
        {
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ],
          "y": "datum.y",
          "x": "datum.x",
          "type": "voronoi"
        }
      ],
      "from": {
        "data": "lines"
      }
    }
  ]
}

# %% [markdown]
# ### Stand-alone specification
# (eg for use with https://vega.github.io/editor/#/)

# %% [markdown]
# Preview region `ETH.5.1_1` <br>
# url `https://waterpeacesecurity.org/api/v1/widget_datapoints/ETH.5.1_1/spi_24/` <br>

# %%
specV5=json.loads("""
{
  "width": 300,
  "height": 300,
  "autosize": {
    "contains": "padding",
    "resize": true,
    "type": "pad"
  },
  "signals": [
    {
      "name": "hover",
      "value": null,
      "on": [
        {
          "update": "datum",
          "events": "@cell:mouseover"
        },
        {
          "update": "null",
          "events": "@cell:mouseout"
        }
      ]
    }
  ],
  "data": [
    {
      "name": "widget_datapoints",
      "url": "https://waterpeacesecurity.org/api/v1/widget_datapoints/ETH.5.1_1/spi_24/",
      "format": {
        "property": "widget_datapoints",
        "type": "json",
        "parse": {
          "month_indep": "date:'%Y-%m-%d'"
        }
      }
    },
    {
      "name": "dots",
      "source": "widget_datapoints",
      "transform": [
        {
          "expr": "hover && hover.datum.month_indep === datum.month_indep",
          "type": "filter"
        }
      ]
    }
  ],
  "scales": [
    {
      "name": "year",
      "type": "linear",
      "range": "width",
      "zero": false,
      "nice": false,
      "domain": {
        "data": "widget_datapoints",
        "field": "year"
      }
    },
    {
      "name": "month_indep",
      "type": "time",
      "range": "width",
      "domain": {
        "data": "widget_datapoints",
        "field": "month_indep"
      }
    },
    {
      "name": "spi_24",
      "type": "linear",
      "range": "height",
      "zero": true,
      "nice": true,
      "domain": {
        "data": "widget_datapoints",
        "field": "spi_24"
      }
    }
  ],
  "axes": [
    {
      "labelOverlap": "parity",
      "scale": "year",
      "format": "4f",
      "zindex": 1,
      "orient": "bottom"
    },
    {
      "title": "24-Month Standard Precipitation Index",
      "scale": "spi_24",
      "labelOverlap": "parity",
      "format": "2s",
      "grid": true,
      "zindex": 0,
      "orient": "left"
    }
  ],
  "marks": [
    {
      "name": "lines",
      "interactive": false,
      "type": "line",
      "encode": {
        "enter": {
          "y": {
            "field": "spi_24",
            "scale": "spi_24"
          },
          "x": {
            "field": "month_indep",
            "scale": "month_indep"
          }
        }
      },
      "from": {
        "data": "widget_datapoints"
      }
    },
    {
      "name": "points",
      "type": "symbol",
      "interactive": false,
      "encode": {
        "update": {
          "opacity": {
            "value": 1
          }
        },
        "enter": {
          "y": {
            "field": "spi_24",
            "scale": "spi_24"
          },
          "x": {
            "field": "month_indep",
            "scale": "month_indep"
          }
        }
      },
      "from": {
        "data": "dots"
      }
    },
    {
      "name": "cell",
      "type": "path",
      "encode": {
        "update": {
          "opacity": {
            "value": 0
          },
          "path": {
            "field": "path"
          },
          "fill": {
            "value": "red"
          }
        },
        "hover": {
          "tooltip": {
            "signal": "{'Standard Precipitation Index': format(hover.datum.spi_24, '.3f'), 'Date': timeFormat(hover.datum.month_indep,'%b %Y')}"
          }
        }
      },
      "transform": [
        {
          "size": [
            {
              "signal": "width"
            },
            {
              "signal": "height"
            }
          ],
          "y": "datum.y",
          "x": "datum.x",
          "type": "voronoi"
        }
      ],
      "from": {
        "data": "lines"
      }
    }
  ]
}
""")
vega5view=dict(specV5)
Vega(vega5view)
